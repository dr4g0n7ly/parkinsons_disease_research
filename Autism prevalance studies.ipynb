# %%
from fastai.imports import *
np.set_printoptions(linewidth=130)

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Datasets/Eye-Tracking Dataset/Eye-tracking Output/1.csv')
dfm = pd.read_csv('Datasets/Eye-Tracking Dataset/Metadata_Participants.csv')
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_25540\1708649199.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('Datasets/Eye-Tracking Dataset/Eye-tracking Output/1.csv')

# %%
def toNumeric(x):
    try:
        return int(x)
    except:
        if (x == 'Unidentified(Neg)'):
            return -1
        elif (x == 'Unidentified(Pos)'):
            return -2
        elif (x == '-'):
            return 0
        
df1['Participant'] = df1['Participant'].apply(lambda x: toNumeric(x) + 1)

df1['Index_Right'] = df1['Index Right'].apply(lambda x: toNumeric(x))
df1['Index_Left'] = df1['Index Left'].apply(lambda x: toNumeric(x))

df1['Pupil_Diameter_Right_[mm]'] = df1['Pupil Diameter Right [mm]'].apply(lambda x: toNumeric(x))
df1['Pupil_Diameter_Left_[mm]'] = df1['Pupil Diameter Left [mm]'].apply(lambda x: toNumeric(x))

df1['Point_of_Regard_Right_X_[px]'] = df1['Point of Regard Right X [px]'].apply(lambda x: toNumeric(x))
df1['Point_of_Regard_Right_Y_[px]'] = df1['Point of Regard Right Y [px]'].apply(lambda x: toNumeric(x))
df1['Point_of_Regard_Left_X_[px]'] = df1['Point of Regard Left X [px]'].apply(lambda x: toNumeric(x))
df1['Point_of_Regard_Left_Y_[px]'] = df1['Point of Regard Left Y [px]'].apply(lambda x: toNumeric(x))

df1['Gaze_Vector_Left_X'] = df1['Gaze Vector Left X'].apply(lambda x: toNumeric(x))
df1['Gaze_Vector_Left_Y'] = df1['Gaze Vector Left Y'].apply(lambda x: toNumeric(x))
df1['Gaze_Vector_Left_Z'] = df1['Gaze Vector Left Z'].apply(lambda x: toNumeric(x))
df1['Gaze_Vector_Right_X'] = df1['Gaze Vector Right X'].apply(lambda x: toNumeric(x))
df1['Gaze_Vector_Right_Y'] = df1['Gaze Vector Right Y'].apply(lambda x: toNumeric(x))
df1['Gaze_Vector_Right_Z'] = df1['Gaze Vector Right Z'].apply(lambda x: toNumeric(x))

df1['Mouse_Position_X_[px]'] = df1['Mouse Position X [px]'].apply(lambda x: toNumeric(x))
df1['Mouse_Position_Y_[px]'] = df1['Mouse Position Y [px]'].apply(lambda x: toNumeric(x))

df1['Scroll_Direction_X'] = df1['Scroll Direction X'].apply(lambda x: toNumeric(x))
df1['Scroll_Direction_Y'] = df1['Scroll Direction Y'].apply(lambda x: toNumeric(x))

# %%
df1 = pd.merge(df1, dfm, on='Participant', how='left')
df1.loc[df1.Participant == -1, 'Class'] = "TD"
df1.loc[df1.Participant == -2, 'Class'] = "ASD"
df1.sort_values(by=['Participant']).head()
# Out:
#        Unnamed: 0  RecordingTime [ms] Time of Day [h:m:s:ms]     Trial  \
# 18112       18112         1307120.335           07:37:58:541  Trial020
# 17971       17971         1302845.157           07:37:54:266  Trial020
# 17972       17972         1302865.032           07:37:54:286  Trial020
# 17973       17973         1302891.206           07:37:54:312  Trial020
# 17974       17974         1302924.662           07:37:54:345  Trial020
#
#                                   Stimulus  Export Start Trial Time [ms]  \
# 18112  20 eye tracking (ballon droite).avi                           0.0
# 17971  20 eye tracking (ballon droite).avi                           0.0
# 17972  20 eye tracking (ballon droite).avi                           0.0
# 17973  20 eye tracking (ballon droite).avi                           0.0
# 17974  20 eye tracking (ballon droite).avi                           0.0
#
#        Export End Trial Time [ms]  Participant       Color  \
# 18112                   52032.952           -1  DarkViolet
# 17971                   52032.952           -1  DarkViolet
# 17972                   52032.952           -1  DarkViolet
# 17973                   52032.952           -1  DarkViolet
# 17974                   52032.952           -1  DarkViolet
#
#        Tracking Ratio [%]  ... Gaze_Vector_Right_Y Gaze_Vector_Right_Z  \
# 18112             65.6507  ...                 NaN                 NaN
# 17971             65.6507  ...                 NaN                 NaN
# 17972             65.6507  ...                 NaN                 NaN
# 17973             65.6507  ...                 NaN                 NaN
# 17974             65.6507  ...                 NaN                 NaN
#
#       Mouse_Position_X_[px] Mouse_Position_Y_[px] Scroll_Direction_X  \
# 18112                     0                     0                  0
# 17971                     0                     0                  0
# 17972                     0                     0                  0
# 17973                     0                     0                  0
# 17974                     0                     0                  0
#
#       Scroll_Direction_Y Gender Age Class CARS Score
# 18112                  0    NaN NaN    TD        NaN
# 17971                  0    NaN NaN    TD        NaN
# 17972                  0    NaN NaN    TD        NaN
# 17973                  0    NaN NaN    TD        NaN
# 17974                  0    NaN NaN    TD        NaN
#
# [5 rows x 59 columns]

# %%
df1.dtypes
# Out:
# Unnamed: 0                        int64
# RecordingTime [ms]              float64
# Time of Day [h:m:s:ms]           object
# Trial                            object
# Stimulus                         object
# Export Start Trial Time [ms]    float64
# Export End Trial Time [ms]      float64
# Participant                       int64
# Color                            object
# Tracking Ratio [%]              float64
# Category Group                   object
# Category Right                   object
# Category Left                    object
# Index Right                      object
# Index Left                       object
# Pupil Diameter Right [mm]        object
# Pupil Diameter Left [mm]         object
# Point of Regard Right X [px]     object
# Point of Regard Right Y [px]     object
# Point of Regard Left X [px]      object
# Point of Regard Left Y [px]      object
# AOI Name Right                   object
# AOI Name Left                    object
# Gaze Vector Right X              object
# Gaze Vector Right Y              object
# Gaze Vector Right Z              object
# Gaze Vector Left X               object
# Gaze Vector Left Y               object
# Gaze Vector Left Z               object
# Annotation Name                  object
# Annotation Description           object
# Annotation Tags                  object
# Mouse Position X [px]            object
# Mouse Position Y [px]            object
# Scroll Direction X               object
# Scroll Direction Y               object
# Content                          object
# Index_Right                       int64
# Index_Left                        int64
# Pupil_Diameter_Right_[mm]       float64
# Pupil_Diameter_Left_[mm]        float64
# Point_of_Regard_Right_X_[px]    float64
# Point_of_Regard_Right_Y_[px]    float64
# Point_of_Regard_Left_X_[px]     float64
# Point_of_Regard_Left_Y_[px]     float64
# Gaze_Vector_Left_X              float64
# Gaze_Vector_Left_Y              float64
# Gaze_Vector_Left_Z              float64
# Gaze_Vector_Right_X             float64
# Gaze_Vector_Right_Y             float64
# Gaze_Vector_Right_Z             float64
# Mouse_Position_X_[px]             int64
# Mouse_Position_Y_[px]             int64
# Scroll_Direction_X                int64
# Scroll_Direction_Y                int64
# Gender                           object
# Age                             float64
# Class                            object
# CARS Score                      float64
# dtype: object

# %%
df1['Scroll Direction X'].value_counts()
# Out:
# -    34630
# Name: Scroll Direction X, dtype: int64

# %%
def proc_data(df):
    
    df['Category_Group'] = df['Category Group']
    df['Category_Group'] = pd.Categorical(df.Category_Group)
    
    df['Category_Left'] = df['Category Left']
    df['Category_Left'] = pd.Categorical(df.Category_Left)
    
    df['Category_Right'] = df['Category Right']
    df['Category_Right'] = pd.Categorical(df.Category_Right)
    
    df['AOI_Name_Left'] = df['AOI Name Left']
    df['AOI_Name_Left'] = pd.Categorical(df.AOI_Name_Left)
    
    df['AOI_Name_Right'] = df['AOI Name Right']
    df['AOI_Name_Right'] = pd.Categorical(df.AOI_Name_Right)
    
    df['Trial'] = pd.Categorical(df.Trial)
    df['Stimulus'] = pd.Categorical(df.Stimulus)
    df['Color'] = pd.Categorical(df.Color)
    df['Class'] = pd.Categorical(df.Class)
    df['Gender'] = pd.Categorical(df.Gender)

    
    df = df.drop(df.loc[df['Category Group']==0].index, inplace=True)
    return df

proc_data(df1)

# %%
df1 = df1.drop(['Time of Day [h:m:s:ms]', 'Mouse Position X [px]', 'Mouse Position Y [px]', 'Gaze Vector Left X', 'Gaze Vector Left Y', 'Gaze Vector Left Z', 'Gaze Vector Right X', 'Gaze Vector Right Y', 'Gaze Vector Right Z', 'Point of Regard Right X [px]', 'Point of Regard Right Y [px]', 'Point of Regard Left X [px]', 'Point of Regard Left Y [px]', 'Pupil Diameter Left [mm]', 'Pupil Diameter Right [mm]','Index Left', 'Index Right', 'Mouse Position X [px]', 'Mouse Position Y [px]', 'Scroll Direction X', 'Scroll Direction Y', 'Content', 'Participant','Unnamed: 0', 'Annotation Name', 'Annotation Description', 'Annotation Tags', 'Category Group', 'Category Right', 'Category Left', 'AOI Name Left', 'AOI Name Right'], axis=1)
df1.head()
# Out:
#    RecordingTime [ms] Time of Day [h:m:s:ms]     Trial  \
# 0         4780015.315           13:22:17:254  Trial020
# 1         4780020.865           13:22:17:260  Trial020
# 2         4780040.758           13:22:17:279  Trial020
# 3         4780080.503           13:22:17:319  Trial020
# 4         4780120.360           13:22:17:359  Trial020
#
#                               Stimulus  Export Start Trial Time [ms]  \
# 0  20 eye tracking (ballon droite).avi                           0.0
# 1  20 eye tracking (ballon droite).avi                           0.0
# 2  20 eye tracking (ballon droite).avi                           0.0
# 3  20 eye tracking (ballon droite).avi                           0.0
# 4  20 eye tracking (ballon droite).avi                           0.0
#
#    Export End Trial Time [ms]  Color  Tracking Ratio [%]  Index_Right  \
# 0                   52058.676  Coral             78.5652            1
# 1                   52058.676  Coral             78.5652            1
# 2                   52058.676  Coral             78.5652            1
# 3                   52058.676  Coral             78.5652            1
# 4                   52058.676  Coral             78.5652            1
#
#    Index_Left  ...  Scroll_Direction_Y  Gender   Age  Class  CARS Score  \
# 0           1  ...                   0       F  10.7     TD         NaN
# 1           1  ...                   0       F  10.7     TD         NaN
# 2           1  ...                   0       F  10.7     TD         NaN
# 3           1  ...                   0       F  10.7     TD         NaN
# 4           1  ...                   0       F  10.7     TD         NaN
#
#    Category_Group  Category_Left  Category_Right  AOI_Name_Left  \
# 0     Information      Separator       Separator              -
# 1             Eye       Fixation        Fixation          corps
# 2             Eye       Fixation        Fixation          corps
# 3             Eye       Fixation        Fixation          corps
# 4             Eye       Fixation        Fixation          corps
#
#    AOI_Name_Right
# 0               -
# 1           corps
# 2           corps
# 3           corps
# 4           corps
#
# [5 rows x 35 columns]

# %%
df1.dtypes
# Out:
# RecordingTime [ms]               float64
# Time of Day [h:m:s:ms]            object
# Trial                           category
# Stimulus                        category
# Export Start Trial Time [ms]     float64
# Export End Trial Time [ms]       float64
# Color                           category
# Tracking Ratio [%]               float64
# Index_Right                        int64
# Index_Left                         int64
# Pupil_Diameter_Right_[mm]        float64
# Pupil_Diameter_Left_[mm]         float64
# Point_of_Regard_Right_X_[px]     float64
# Point_of_Regard_Right_Y_[px]     float64
# Point_of_Regard_Left_X_[px]      float64
# Point_of_Regard_Left_Y_[px]      float64
# Gaze_Vector_Left_X               float64
# Gaze_Vector_Left_Y               float64
# Gaze_Vector_Left_Z               float64
# Gaze_Vector_Right_X              float64
# Gaze_Vector_Right_Y              float64
# Gaze_Vector_Right_Z              float64
# Mouse_Position_X_[px]              int64
# Mouse_Position_Y_[px]              int64
# Scroll_Direction_X                 int64
# Scroll_Direction_Y                 int64
# Gender                          category
# Age                              float64
# Class                           category
# CARS Score                       float64
# Category_Group                  category
# Category_Left                   category
# Category_Right                  category
# AOI_Name_Left                   category
# AOI_Name_Right                  category
# dtype: object

# %%
cats = [column for column, dtype in df1.dtypes.items() if dtype.name == 'category']
conts = [column for column, dtype in df1.dtypes.items() if dtype == 'float64'] + [column for column, dtype in df1.dtypes.items() if dtype == 'int64']
dep = "Class"
cats, conts, dep
# Out:
# (['Trial',
#   'Stimulus',
#   'Color',
#   'Gender',
#   'Class',
#   'Category_Group',
#   'Category_Left',
#   'Category_Right',
#   'AOI_Name_Left',
#   'AOI_Name_Right'],
#  ['RecordingTime [ms]',
#   'Export Start Trial Time [ms]',
#   'Export End Trial Time [ms]',
#   'Tracking Ratio [%]',
#   'Pupil_Diameter_Right_[mm]',
#   'Pupil_Diameter_Left_[mm]',
#   'Point_of_Regard_Right_X_[px]',
#   'Point_of_Regard_Right_Y_[px]',
#   'Point_of_Regard_Left_X_[px]',
#   'Point_of_Regard_Left_Y_[px]',
#   'Gaze_Vector_Left_X',
#   'Gaze_Vector_Left_Y',
#   'Gaze_Vector_Left_Z',
#   'Gaze_Vector_Right_X',
#   'Gaze_Vector_Right_Y',
#   'Gaze_Vector_Right_Z',
#   'Age',
#   'CARS Score',
#   'Index_Right',
#   'Index_Left',
#   'Mouse_Position_X_[px]',
#   'Mouse_Position_Y_[px]',
#   'Scroll_Direction_X',
#   'Scroll_Direction_Y'],
#  'Class')

# %% [markdown]
# ## Decision Tree

# %%
from numpy import random
from sklearn.model_selection import train_test_split

random.seed(42)
trn_df,val_df = train_test_split(df1, test_size=0.25)
trn_df[cats] = trn_df[cats].apply(lambda x: x.cat.codes)
val_df[cats] = val_df[cats].apply(lambda x: x.cat.codes)

# %%
def xs_y(df):
    xs = df[cats+conts].copy()
    return xs,df[dep] if dep in df else None

trn_xs,trn_y = xs_y(trn_df)
val_xs,val_y = xs_y(val_df)

# %% [markdown]
# ## Random Forest

# %%
def get_tree(prop=0.75):
    n = len(test1)
    idxs = random.choice(n, int(n*prop))
    return DecisionTreeClassifier(min_samples_leaf=5).fit(trn_xs.iloc[idxs], trn_y.iloc[idxs])

# %%
trees = [get_tree() for t in range(20)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25540\954991145.py in <module>
# ----> 1 trees = [get_tree() for t in range(20)]
#
# ~\AppData\Local\Temp\ipykernel_25540\954991145.py in <listcomp>(.0)
# ----> 1 trees = [get_tree() for t in range(20)]
#
# ~\AppData\Local\Temp\ipykernel_25540\2929918281.py in get_tree(prop)
#       2     n = len(test1)
#       3     idxs = random.choice(n, int(n*prop))
# ----> 4     return DecisionTreeClassifier(min_samples_leaf=5).fit(trn_xs.iloc[idxs], trn_y.iloc[idxs])
#
# D:\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# D:\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165             X, y = self._validate_data(
#     166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#
# D:\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     576                 # :(
#     577                 check_X_params, check_y_params = validate_separately
# --> 578                 X = check_array(X, **check_X_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
#
# D:\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# D:\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz

m = DecisionTreeClassifier(max_leaf_nodes=4).fit(train1, tr);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25540\1119245185.py in <module>
#       1 from sklearn.tree import DecisionTreeClassifier, export_graphviz
#       2
# ----> 3 m = DecisionTreeClassifier(max_leaf_nodes=4).fit(trn_xs, trn_y);
#
# NameError: name 'trn_xs' is not defined
